# %% [markdown]
# # Antonio Rafael Cedillo
# Programa: Provincias con aguacates mas consumidos en cada
# 1. Mostrar la DF completa.

# %%
import pandas as pd

ag = pd.read_csv("avocado.csv")
ag
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %% [markdown]
# Usando groupby, scamos los maximos valores.

# %%
#intento con Moises
ag['Date'] = pd.to_datetime(ag['Date'])

ag.groupby([ag.Date.dt.month, ag.region]).sum('Total Bags')
# Out:
#                           Unnamed: 0  AveragePrice  Total Volume  \
# Date region
# 1    Albany                     1462         55.37  1.715397e+06
#      Atlanta                    1462         48.64  9.951652e+06
#      BaltimoreWashington        1462         50.53  1.534040e+07
#      Boise                      1462         43.94  1.625353e+06
#      Boston                     1462         52.52  1.117448e+07
# ...                              ...           ...           ...
# 12   Syracuse                     44         36.75  7.095094e+05
#      Tampa                        44         34.31  5.106522e+06
#      TotalUS                      44         32.68  4.099263e+08
#      West                         44         29.65  7.650755e+07
#      WestTexNewMexico             41         30.56  9.782226e+06
#
#                                   4046          4225        4770  \
# Date region
# 1    Albany               4.327958e+04  1.385227e+06     4679.02
# ...

# %%
#Intento mio 


ag['Date'] = pd.to_datetime(ag['Date'])

def maxConsumo(mes):
    regionesCount = ag.region.value_counts()
    regiones = regionesCount.index
    print(regiones)

    totalesCount = ag['Total Bags'].value_counts()
    totales = totalesCount.index
    print(totales)


    fechas = ag.Date.dt.month
    print(fechas)

    sumas = []


        
        


maxConsumo(1)
# Out:
# Index(['Albany', 'Sacramento', 'Northeast', 'NorthernNewEngland', 'Orlando',
#        'Philadelphia', 'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'SanDiego',
#        'Atlanta', 'SanFrancisco', 'Seattle', 'SouthCarolina', 'SouthCentral',
#        'Southeast', 'Spokane', 'StLouis', 'Syracuse', 'Tampa', 'TotalUS',
#        'West', 'NewYork', 'NewOrleansMobile', 'Nashville', 'Midsouth',
#        'BaltimoreWashington', 'Boise', 'Boston', 'BuffaloRochester',
#        'California', 'Charlotte', 'Chicago', 'CincinnatiDayton', 'Columbus',
#        'DallasFtWorth', 'Denver', 'Detroit', 'GrandRapids', 'GreatLakes',
#        'HarrisburgScranton', 'HartfordSpringfield', 'Houston', 'Indianapolis',
#        'Jacksonville', 'LasVegas', 'LosAngeles', 'Louisville',
#        'MiamiFtLauderdale', 'WestTexNewMexico'],
#       dtype='object', name='region')
# Index([      0.0,     990.0,     300.0,     550.0,    266.67,    916.67,
# ...
