# %% [markdown]
# # Antonio Rafael Cedillo A012656823
# ## Actividad Evaluable: Mapas de calor y boxplots
#
# ## Covid-19 Tweets
#
# ### Autores:
# - Moisés Adame Aguilar (A01660927)
# - Luis Armando Mandujano Chávez (A01655899)
# - Antonio Rafael Cedillo Ródriguez (A01656823)

# %% [markdown]
# ### Carga de datos usando pandas.

# %%
import pandas as pd #se importa pandas para poder leer el csv

df = pd.read_csv("covid19_tweets.csv")
df #Se verifica que la base de datos este correcta.
# Out:
#                       user_name         user_location  \
# 0                        ᏉᎥ☻լꂅϮ            astroworld
# 1                 Tom Basile 🇺🇸          New York, NY
# 2               Time4fisticuffs      Pewee Valley, KY
# 3                   ethel mertz  Stuck in the Middle
# 4                      DIPR-J&K     Jammu and Kashmir
# ...                         ...                   ...
# 74431             Laura Wolfrom         Lexington, KY
# 74432  Professor Tonya M. Evans         😷 #stayathome
# 74433        People's Daily app           北京, 中华人民共和国
# 74434                     M0ser                   NaN
# 74435    Your Friend & Sabre ⚔️           Chicago, IL
#
#                                         user_description         user_created  \
# 0      wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1      Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2      #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# ...

# %% [markdown]
# ## 2. Analisis de variables con el uso de diversas graficas.
#
# ### 2.1 Cajas y bigotes. (Solo valores numericos)

# %%
import seaborn as sb

#Creando cajas/bigotes de cada variable numerica con su respectivo titulo para diferenciar cual es cual
sb.boxplot(data = df["user_followers"],showfliers=False).set(title="User followers")
# Out:
# [Text(0.5, 1.0, 'User followers')]

# %%
sb.boxplot(data = df["user_friends"],showfliers=False).set(title="User friends")
# Out:
# [Text(0.5, 1.0, 'User friends')]

# %%
sb.boxplot(data = df["user_favourites"],showfliers=False).set(title="User favourites")
# Out:
# [Text(0.5, 1.0, 'User favourites')]

# %% [markdown]
# ### 2.2 Histogramas

# %%
import matplotlib.pyplot as plt #Importando librerias para la graficación de histograma

fig, ax = plt.subplots()
ax.hist(df["user_followers"])
plt.title("User followers")
plt.show()

# %%
fig, ax = plt.subplots()
ax.hist(df["user_friends"])
plt.title("User friends")
plt.show()

# %%
fig, ax = plt.subplots()
ax.hist(df["user_favourites"])
plt.title("User favourites")
plt.show()

# %% [markdown]
# ### Pre 2.3 Correlación
#
# Para crear los siguientes dos diagramas (histogramas y de calor, es necesario) sacar la correlación del dataframe.

# %%
df.corr(numeric_only=True)
# Out:
#                  user_followers  user_friends  user_favourites  user_verified  \
# user_followers         1.000000     -0.002722        -0.028724       0.322896
# user_friends          -0.002722      1.000000         0.207825       0.013099
# user_favourites       -0.028724      0.207825         1.000000      -0.060316
# user_verified          0.322896      0.013099        -0.060316       1.000000
# is_retweet                  NaN           NaN              NaN            NaN
#
#                  is_retweet
# user_followers          NaN
# user_friends            NaN
# user_favourites         NaN
# user_verified           NaN
# is_retweet              NaN

# %% [markdown]
# ### 2.3 Mapas de calor

# %%
sb.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %% [markdown]
# ## Respondiendo preguntas

# %% [markdown]
# - ¿Hay alguna variable que no aporta información?
#
# En este caso, hay variables que no son compatibles con todos estos calculos de graficos, en este caso siendo todas las variables no numericas (se consideran es verificado o es retweet se cuentan como numericos, aunque son booleanos), pero para tener calculos mas precios y menos confusos, igualmente consideraria is_verified y is_retweet como variables que no aportan.
#
#
# - Si tuvieras que eliminar variables, ¿cuáles quitarías y por qué?
#
# Aparte de las variables no numericas, quitaria las variables booleanas antes mencionadas, para tener calculos correctos y mas precisos o confusos y que no haya errores al usar los codigos para graficar.
#
# - ¿Existen variables que tengan datos extraños?
#
# Si, especialmente en los calculos de correlación y mapa de calor, ya que al usar "numeric only = true" se cuenta los valores booleanos como numericos (una teoria mia es que el booleano se puede ver como 1 o 0, dependiendo de verdadero o falso, entonces toma estos numeros que representan el booleano.)
#
# - Si comparas las variables, ¿todas están en rangos similares? ¿Crees que esto afecte?¿
#
# No todas estan en rangos distintos, esto puede afectar ya que refleja la diferencias entre usuarios (siendo usuarios "promedio", usuarios relevantemente grandes, influencers o famosos o cuentas que son seguidas automaticamente como el bot de twitter/X)
#
# - ¿Puedes encontrar grupos qué se parezcan? ¿Qué grupos son estos?
#
# El unico grupo que se parecen o tienen la mayor correlación positivia es user_verified y user_followers, que es muy extraño, ya que una es una variable numerica y otra es booleana.
